# %% [markdown]
# ## Preparation
#
# You need to setup the TECHIN515 virtual environment to run this lab

# %% [markdown]
# # TECHIN 515: Quantization and Pruning Methods
#
# In this lab, we will first go through three (post training) quantization methods: (1) Float-16 Quantization, (2) Dynamic Range Quantization, and (3)Integer Quantization. Then we try out strip pruning for model compression.
#
# We will use Efficient Net (`efnet`) ML model as our base ML model and download and use `CIFAR-10` dataset for training and testing ML models.
#
# Before working on the code, we will need to setup the environment. The following code will display the current version of the tensorflow if you have already installed it in your machine.

# %% [markdown]
# In the following we will install `tensorflow_datasets` and `tensorflow_model_optimization` libraries.

# %%
pip install tensorflow_datasets
# Out:
# Requirement already satisfied: tensorflow_datasets in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (4.9.8)
# Requirement already satisfied: absl-py in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (1.4.0)
# Requirement already satisfied: dm-tree in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (1.12.2)
# Requirement already satisfied: immutabledict in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (4.2.1)
# Requirement already satisfied: numpy in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (1.26.4)
# Requirement already satisfied: promise in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (5.29.4)
# Requirement already satisfied: psutil in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (7.0.0)
# Requirement already satisfied: pyarrow in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (19.0.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (2.32.3)
# Requirement already satisfied: simple_parsing in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (1.17.1)
# Requirement already satisfied: termcolor in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (3.0.1)
# Requirement already satisfied: toml in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: tqdm in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (4.67.1)
# Requirement already satisfied: wrapt in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_datasets) (1.17.2)
# Requirement already satisfied: einops in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (0.8.1)
# Requirement already satisfied: fsspec in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (2025.3.2)
# Requirement already satisfied: importlib_resources in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (4.13.2)
# Requirement already satisfied: zipp in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2025.1.31)
# Requirement already satisfied: attrs>=18.2.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from dm-tree->tensorflow_datasets) (25.3.0)
# Requirement already satisfied: six in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from promise->tensorflow_datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from simple_parsing->tensorflow_datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow-metadata->tensorflow_datasets) (1.70.0)
# Requirement already satisfied: colorama in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tqdm->tensorflow_datasets) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install tensorflow_model_optimization
# Out:
# Requirement already satisfied: tensorflow_model_optimization in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (0.8.0)
# Requirement already satisfied: absl-py~=1.2 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_model_optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_model_optimization) (0.1.9)
# Requirement already satisfied: numpy~=1.23 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_model_optimization) (1.26.4)
# Requirement already satisfied: six~=1.14 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow_model_optimization) (1.17.0)
# Requirement already satisfied: attrs>=18.2.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from dm-tree~=0.1.1->tensorflow_model_optimization) (25.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from dm-tree~=0.1.1->tensorflow_model_optimization) (1.17.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (79.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Next we will first download and load `CIFAR-10` dataset, load and retrain `efnet` ML model, and experiment with three (post training) quantization methods: (1) Float-16 Quantization, (2) Dynamic Range Quantization, and (3) Integer Quantization.
#
# The following code and material were adapted from the reference [1].

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\jaden\documents\github\msti\q3\techin 515\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importing necessary libraries and packages.
import os
import pandas as pd
from IPython.display import display
import numpy as np
import tempfile
import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
from tensorflow.keras.models import Model
import tensorflow_model_optimization as tfmot
from tensorflow.keras.layers import Dropout, Dense, BatchNormalization
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# ## (1) Preparing the Dataset with CIFAR-10
#
# We will use the CIFAR-10 dataset for this project. CIFAR-10 contains 60,000 32x32 color images in 10 classes. For simplicity, we will use only two classes (e.g., 'airplane' and 'automobile') for binary classification. The dataset will be split into training, validation, and testing sets.

# %%
# Downloading and Loading the CIFAR-10 dataset.
(train_ds, val_ds, test_ds), info = tfds.load('cifar10', split=['train[:70%]', 'train[70%:90%]', 'train[90%:]'], shuffle_files=True, as_supervised=True, with_info=True)

# %% [markdown]
# Let us now filter the dataset to include only two classes: 'airplane' and 'automobile'.

# %%
# Filtering the dataset to include only 'airplane' and 'automobile' classes.
def filter_classes(image, label):
    return tf.math.logical_or(tf.equal(label, 0), tf.equal(label, 1))

def map_labels(image, label):
    return image, tf.where(label == 0, 0, 1)

train_ds = train_ds.filter(filter_classes).map(map_labels)
val_ds = val_ds.filter(filter_classes).map(map_labels)
test_ds = test_ds.filter(filter_classes).map(map_labels)

# %% [markdown]
# We will now preprocess the dataset by resizing the images to 224x224 and batching them for training.

# %%
# Preprocessing the dataset.
batch_size = 16
img_size = [224, 224]

train_ds_ = train_ds.cache().map(lambda x, y: (tf.image.resize(x, img_size), y)).batch(batch_size).prefetch(buffer_size=10)
val_ds_ = val_ds.cache().map(lambda x, y: (tf.image.resize(x, img_size), y)).batch(batch_size).prefetch(buffer_size=10)
test_ds_ = test_ds.cache().map(lambda x, y: (tf.image.resize(x, img_size), y)).batch(batch_size).prefetch(buffer_size=10)

# %% [markdown]
# The CIFAR-10 dataset is now ready for training and evaluation. We will proceed with the same model architecture and quantization methods as before.

# %% [markdown]
# To feed images to the TF Lite model, we need to extract the test images and their labels. We will store them into variables and feed them to TF Lite for evaluation.

# %%
# Extracting and saving test images and labels from the test dataset.
test_images = []
test_labels = []
for image, label in test_ds_.unbatch():  # Remove `.take(len(test_ds_))`
    test_images.append(image.numpy())  # Convert tensors to numpy arrays
    test_labels.append(label.numpy())  # Convert tensors to numpy arrays

# Convert lists to numpy arrays for easier processing later
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %% [markdown]
# ## (2) Loading the Model
#
# We have chosen the EfiicientNet B0 model pre-trained on the imagenet dataset for image classification purposes. EfficientNet is a state-of-the-art image classification model. It significantly outperforms other ConvNets.
#
# Let us import the model form tf.keras.applications().  The last layer has been removed by setting include_top = False .We have set the input image size to 224×224 pixels and kept the pooling layer to be GlobalMaxPooling2D. Let’s load the model and unfreeze all the layers to make them trainable.

# %%
# Defining the model architecture.
efnet = tf.keras.applications.EfficientNetB0(include_top = False, weights ='imagenet', input_shape = (224, 224, 3), pooling = 'max')# Unfreezing all the layers of the model.
for layer in efnet.layers:
    set_trainable = True

# %% [markdown]
# Now, we will add a Dense layer to the pre-trained model and train it. This layer will become the last layer, or the inference layer. We will also add Dropout and BatchNormalization to reduce overfitting.

# %%
# Adding Dense, BatchNormalization and Dropout layers to the base model.
x = Dense(512, activation='relu')(efnet.output)
x = BatchNormalization()(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(2, activation='softmax')(x)

# %% [markdown]
# ## (3) Compiling the Model
#
# We are ready to compile the model. We have used Adam Optimizer with an initial learning rate of 0.0001, sparse categorical cross-entropy as the loss function, and accuracy as the metric. Once compiled, we check the model summary.

# %%
# Defining the input and output layers of the model.
model = Model(inputs=efnet.input, outputs=predictions)
 
# Compiling the model.
model.compile(optimizer=tf.keras.optimizers.Adam(0.0001), loss =tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), metrics = ["accuracy"])
 
# Obtaining the model summary.
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 224, 224,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 224, 224,  │          0 │ normalization[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 225, 225,  │          0 │ rescaling_1[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 112, 112,  │        864 │ stem_conv_pad[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 112, 112,  │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 112, 112,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 112, 112,  │        288 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 112, 112,  │        128 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 112, 112,  │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 112, 112,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 112, 112,  │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 112, 112,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 112, 112,  │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 112, 112,  │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 112, 112,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 113, 113,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 56, 56,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 56, 56,    │        384 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 56, 56,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 56, 56,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 56, 56,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 56, 56,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 56, 56,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 56, 56,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 56, 56,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 56, 56,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 56, 56,    │        576 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 56, 56,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 56, 56,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 56, 56,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 56, 56,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 56, 56,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 56, 56,    │          0 │ block2b_drop[0][… │
# │                     │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 56, 56,    │      3,456 │ block2b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 56, 56,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 56, 56,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 59, 59,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 28, 28,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 28, 28,    │        576 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 28, 28,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 28, 28,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 28, 28,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 28, 28,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 28, 28,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 28, 28,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 28, 28,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 28, 28,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 28, 28,    │        960 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 28, 28,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 28, 28,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 28, 28,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None,
│ block6d_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn   │ (None, 7, 7,      │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 7, 7,      │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv      │ (None, 7, 7,      │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn          │ (None, 7, 7,      │      4,608 │ block7a_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation  │ (None, 7, 7,      │          0 │ block7a_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze  │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape  │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 7, 7,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 7, 7, 320) │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 7, 7, 320) │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 7, 7,      │    409,600 │ block7a_project_… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 7, 7,      │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 7, 7,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pool            │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    655,872 │ max_pool[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 512)       │      2,048 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │     32,832 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 2)         │        130 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,740,453 (18.08 MB)
#  Trainable params: 4,697,406 (17.92 MB)
#  Non-trainable params: 43,047 (168.16 KB)

# %% [markdown]
# We are using Model Saving Callback and the Reduce LR Callback.
#
# (i) Model Saving Callback saves the model with the best validation accuracy
#
# (ii) Reduce LR Callback reduces the learning rate by a factor of 0.1 if validation loss remains the same for three consecutive epochs.

# %%
# Defining file path of the saved model.
filepath = './model.h5'
 
# Defining Model Save Callback and Reduce Learning Rate Callback.
model_save = tf.keras.callbacks.ModelCheckpoint(
    filepath,
    monitor="val_accuracy",
    verbose=0,
    save_best_only=True,
    save_weights_only=False,
    mode="max",
    save_freq="epoch")
 
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.1, patience=3, verbose=1, min_delta=5*1e-3,min_lr =5*1e-9,)
 
callback = [model_save, reduce_lr]

# %% [markdown]
# ### Discussion:
# - What is the input size?
# - Based on model summary, name two examples of layers used in the architecture

# %% [markdown]
# ### Discussion Answers:
#
# Since the model uses images, the size is set earlier when we use `input_shape = (224, 224, 3)`. I.e. a 224x224 pixel image with 3 color channels. We used dense layers for classification, and a layer for batch normalization.

# %% [markdown]
# ## (4) Training the Model
#
# The method `model.fit()` is called to train the model. We pass the training and validation datasets and train the model for 15 epochs.

# %%
# Calculate the number of steps per epoch manually
# Ensure we have at least 1 step per epoch to avoid math domain errors
train_steps_per_epoch = max(1, tf.data.experimental.cardinality(train_ds_).numpy())
val_steps_per_epoch = max(1, tf.data.experimental.cardinality(val_ds_).numpy())

# Training the model for 3 epochs (for testing purposes)
model.fit(
    train_ds_,
    epochs=3,
    steps_per_epoch=10,  # Using a fixed value to avoid calculation errors
    validation_data=val_ds_,
    validation_steps=5,  # Using a fixed value to avoid calculation errors
    shuffle=False,
    callbacks=callback
)
# Out:
# Epoch 1/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.5678 - loss: 0.9002
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 671ms/step - accuracy: 0.5679 - loss: 0.8973 - val_accuracy: 0.6250 - val_loss: 0.8838 - learning_rate: 1.0000e-04
# Epoch 2/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.6651 - loss: 0.7388
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 533ms/step - accuracy: 0.6655 - loss: 0.7339 - val_accuracy: 0.7625 - val_loss: 0.4309 - learning_rate: 1.0000e-04
# Epoch 3/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.7456 - loss: 0.4759
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 534ms/step - accuracy: 0.7483 - loss: 0.4763 - val_accuracy: 0.8750 - val_loss: 0.3223 - learning_rate: 1.0000e-04

# %% [markdown]
# ## (5) Evaluating the Model
#
# Done training! Let’s check the model’s performance on the test set.

# %%
# Evaluating the model on the test dataset.
_, baseline_model_accuracy = model.evaluate(test_ds_, verbose=0)
print('Baseline test accuracy:', baseline_model_accuracy*100)
# Out:
# Baseline test accuracy: 84.51143503189087
# c:\Users\jaden\Documents\GitHub\MSTI\Q3\TECHIN 515\.venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()

#
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863423248: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# We have passed the Float 16 quantization the `converter.target_spec.supported_type` to specify the type of quantization. The rest of the code remains the same for a general way of conversion for the TF Lite Model. In order to get model accuracy, let’s first define evaluate() function that takes in tflite model and returns model accuracy.

# %%
#Function for evaluating TF Lite Model over Test Images
def evaluate(interpreter):
    prediction= []
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]
    input_format = interpreter.get_output_details()[0]['dtype']
    
    for i, test_image in enumerate(test_images):
        if i % 100 == 0:
            print('Evaluated on {n} results so far.'.format(n=i))
        test_image = np.expand_dims(test_image, axis=0).astype(input_format)
        interpreter.set_tensor(input_index, test_image)

        # Run inference.
        interpreter.invoke()
        output = interpreter.tensor(output_index)
        predicted_label = np.argmax(output()[0])
        prediction.append(predicted_label)
    
    print('\n')
    # Comparing prediction results with ground truth labels to calculate accuracy.
    prediction = np.array(prediction)
    accuracy = (prediction == test_labels).mean()
    return accuracy

# %% [markdown]
# Check this FP-16 Quantized TF Lite’s model performance on the Test Set.

# %%
# Passing the FP-16 TF Lite model to the interpreter.
interpreter = tf.lite.Interpreter('fp_16_model.tflite')
# Allocating tensors.
interpreter.allocate_tensors()
# Evaluating the model on the test dataset.
test_accuracy = evaluate(interpreter)
print('Float 16 Quantized TFLite Model Test Accuracy:', test_accuracy*100)
print('Baseline Keras Model Test Accuracy:', baseline_model_accuracy*100)
# Out:
# c:\Users\jaden\Documents\GitHub\MSTI\Q3\TECHIN 515\.venv\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# Evaluated on 0 results so far.
# Evaluated on 100 results so far.
# Evaluated on 200 results so far.
# Evaluated on 300 results so far.
# Evaluated on 400 results so far.
# Evaluated on 500 results so far.
# Evaluated on 600 results so far.
# Evaluated on 700 results so far.
# Evaluated on 800 results so far.
# Evaluated on 900 results so far.
#
#
# Float 16 Quantized TFLite Model Test Accuracy: 84.3035343035343
# Baseline Keras Model Test Accuracy: 84.51143503189087

# %% [markdown]
# ### Discussion
# - Compare the model performance when float 16 quantization is used with the original model performance
# - Briefly explain your observation

# %% [markdown]
# ### Discussion Answers
#
# The float 16 quantization caused the size of the model to decrease by 83.6%, while only losing .21% accuracy (84.51% to 84.30%). This is due to the bits being changed from 32 to 16, which also means some data is lost overall (but minimal amounts, as shown by the accuracy change).

# %% [markdown]
# ## (7) Dynamic Range Quantization
#
# In Dynamic Range Quantization, weights are converted to 8-bit precision values.

# %%
# Passing the baseline Keras model to the TF Lite Converter.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
# Using  the Dynamic Range Quantization.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Converting the model
tflite_quant_model = converter.convert()
# Saving the model.
with open('./dynamic_quant_model.tflite', 'wb') as f:
    f.write(tflite_quant_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\jaden\AppData\Local\Temp\tmpcy5ldj2u\assets
# INFO:tensorflow:Assets written to: C:\Users\jaden\AppData\Local\Temp\tmpcy5ldj2u\assets
# Saved artifact at 'C:\Users\jaden\AppData\Local\Temp\tmpcy5ldj2u'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   2096863417872: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2096863418256: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2096834426832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837306384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837307536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837308880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837308304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837308496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837311376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837312144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837311184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837310224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842490512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842491664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842491856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842492624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842490704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842493392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842494160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842493008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842492816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842495120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842494352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842492432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842494736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842496080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842497232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842496464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842495696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842496848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842498192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842499344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842499536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842499728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842500496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842500688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842500880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842502224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842501456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842501072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842503184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842502800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842504144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842503376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842501264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842505104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842503568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842501648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842505296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842500112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842505872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842851536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842851152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842851728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842852112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842852880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842853648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842852496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842852304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842853072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842854992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842855952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842855184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842853840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842856912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842856528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842857872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842857104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842854800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842858832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842859024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842857296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842859408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842855376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842860560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842861328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842860176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842859984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842862288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842861904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842863248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842862480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842859216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842864208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842863824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842865168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842864400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842854224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842866128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842865360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842866320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842862672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096842865744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859940240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859939280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859940048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859939088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859939856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859942160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859943120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859942352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859941008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859944080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859943696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859945040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859944272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859941968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859946000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859946192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859944464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859946576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859942544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859947728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859948496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859947344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859947152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859949456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859949072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859950416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859949648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859946384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859951376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859950992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859952336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859951568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859941392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859953296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859953488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859951760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859953872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859949840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859955024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860430608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096859953680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860431568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860432336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860433296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860432528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860430416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860434256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860433872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860435216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860434448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860432144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860436176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860436368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860434640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860436752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860432720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860437904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860438672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860437520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860437328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860438096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860440016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860440976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860440208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860438864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860441936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860441552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860442896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860442128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860439824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860443856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860444048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860442320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860444432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860440400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860445584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860446544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860445200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860445008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860445776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860840208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860841360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860444240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860841168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860842512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860842128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860843472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860842704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860840976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860844432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860844624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860842896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860845008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860840592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860846160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860846928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860845776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860845584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860846352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860848272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860849232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860848464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860847120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860850192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860849808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860851152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860850384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860848080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860852112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860852304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860850576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860852688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860848656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860853840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860854608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860853456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860853264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860854032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860855952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861266960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860855184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096860855760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861267536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861266192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861268496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861267728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861266768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861269456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861269648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861267920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861270032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861266384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861271184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861271952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861270800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861270608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861272912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861272528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861273872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861273104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861269840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861274832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861274448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861275792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861275024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861266000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861276752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861276944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861275216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861277328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861273296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861278480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861279248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861278096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861277904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861278672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861280592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861281552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861280784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861279440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861281360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862889168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862888208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861282128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096861280400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862890128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862890320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862888976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862890704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862889360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862891856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862892624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862891472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862891280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862892048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862893968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862894928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862894160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862892816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862895888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862895504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862896848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862896080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862893776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862897808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862898000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862896272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862898384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862894352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862899536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862900304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862899152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862898960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862893200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862901840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862902800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862902032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862901264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862903760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862903952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862903376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862902992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096862901456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863412688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863413840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863413264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863414224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863413456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863415376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863416144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863414992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863414800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863417104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863416720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863418064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863417296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863414032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837306192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863417488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863419024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863419408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863412880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863419792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863421328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863421904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863415568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863423248: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# Let’s evaluate this TF Lite model on the test dataset.

# %%
# Passing the Dynamic Range Quantized TF Lite model to the Interpreter.
interpreter = tf.lite.Interpreter('dynamic_quant_model.tflite') 
# Allocating tensors.
interpreter.allocate_tensors()
# Evaluating the model on the test images.
test_accuracy = evaluate(interpreter)
print('Dynamically  Quantized TFLite Model Test Accuracy:', test_accuracy*100)
print('Baseline Keras Model Test Accuracy:', baseline_model_accuracy*100)
# Out:
# c:\Users\jaden\Documents\GitHub\MSTI\Q3\TECHIN 515\.venv\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# Evaluated on 0 results so far.
# Evaluated on 100 results so far.
# Evaluated on 200 results so far.
# Evaluated on 300 results so far.
# Evaluated on 400 results so far.
# Evaluated on 500 results so far.
# Evaluated on 600 results so far.
# Evaluated on 700 results so far.
# Evaluated on 800 results so far.
# Evaluated on 900 results so far.
#
#
# Dynamically  Quantized TFLite Model Test Accuracy: 84.40748440748442
# Baseline Keras Model Test Accuracy: 84.51143503189087

# %% [markdown]
# ### Discussion
# - Compare the model performance when dynamic range quantization is used with the original model performance
# - Briefly explain your observation

# %% [markdown]
# ### Discussion Answers
#
# This one reduced the size even more than 16 bit, and was actually a bit more accurate than the float 16 quantization (still slightly less accurate than baseline however). The accuracy slightly reduced to 84.41% from 84.51%, and it reduced the size by 83.6%, which is a large amount. This is due to unneeded informaiton being taken out of the representations for each neural.

: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863414992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863414800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863417104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863416720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863418064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863417296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863414032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096837306192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863417488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863419024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863419408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863412880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863419792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863421328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863421904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863415568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2096863423248: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\jaden\Documents\GitHub\MSTI\Q3\TECHIN 515\.venv\Lib\site-packages\tensorflow\lite\python\convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(

# %% [markdown]
# Let’s evaluate the obtained Integer Quantized TF Lite model on the test dataset.

# %%
# Passing the Integer Quantized TF Lite model to the Interpreter.
interpreter = tf.lite.Interpreter('./int_quant_model.tflite')
# Allocating tensors.
interpreter.allocate_tensors()
# Evaluating the model on the test images.
test_accuracy = evaluate(interpreter)
print('Integer Quantized TFLite Model Test Accuracy:', test_accuracy*100)
print('Baseline Keras Model Test Accuracy:', baseline_model_accuracy*100)
# Out:
# c:\Users\jaden\Documents\GitHub\MSTI\Q3\TECHIN 515\.venv\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# Evaluated on 0 results so far.
# Evaluated on 100 results so far.
# Evaluated on 200 results so far.
# Evaluated on 300 results so far.
# Evaluated on 400 results so far.
# Evaluated on 500 results so far.
# Evaluated on 600 results so far.
# Evaluated on 700 results so far.
# Evaluated on 800 results so far.
# Evaluated on 900 results so far.
#
#
# Integer Quantized TFLite Model Test Accuracy: 74.42827442827443
# Baseline Keras Model Test Accuracy: 84.51143503189087

# %% [markdown]
# ### Discussion:
# - Compare the model performance using float 16, dynamic range, and integer quantization
# - Based on our in-class discussion, explain your observation

# %% [markdown]
# ### Discussion Answers
#
# Dynamic range ended up having the best values for both compression and accuracy, as it reduces the size to levels similar to the integer quantization, however it retains the accuracy of the baseline much better. All three of these quantization methods reduce the size of the model and reduce the accuracy through different bit representations, but integer quantization seems to do this in the "worst" way.
#
# I'm not sure how our in-class discussion explains why these three methods have different performances since we really only looked at quantization vs. pruning, and this section is different ways of performing quantization compression. From an overall standpoint though, quantization reduces the size and accuracy since the "neurals are being represented with less bits", according to the lecture slides.

# %% [markdown]
# ## (9) Model Pruning
#
# You will apply pruning to the whole model and see this in the model summary. In this example, you start the model with 50% sparsity (50% zeros in weights) and end with 80% sparsity. Also note that pruning can be only applied to the dense layers.
#
# The following code and material were adapted from the reference [2].

# %%
# Import necessary libraries
import tensorflow as tf
import tensorflow_model_optimization as tfmot
import numpy as np
import tempfile

# Define pruning parameters
batch_size = 16
epochs = 2
validation_split = 0.1

# Create input data for calculation
train_images = []
train_labels = []
for image_batch, label_batch in train_ds_.take(10):
    for i in range(len(image_batch)):
        train_images.append(image_batch[i].numpy())
        train_labels.append(label_batch[i].numpy())

train_images = np.array(train_images)
train_labels = np.array(train_labels)

# Calculate end step
NUM_TRAIN_IMAGES = train_images.shape[0] * (1 - validation_split)
num_images = NUM_TRAIN_IMAGES
end_step = np.ceil(num_images / batch_size).astype(np.int32) * epochs

# Create a simpler model than the EfficientNet for demonstration purposes
# This is a Functional model but with fewer layers to simplify the demonstration
inputs = tf.keras.layers.Input(shape=(224, 224, 3))
x = tf.keras.layers.Conv2D(32, 3, activation='relu')(inputs)
x = tf.keras.layers.MaxPooling2D()(x)
x = tf.keras.layers.Conv2D(64, 3, activation='relu')(x)
x = tf.keras.layers.MaxPooling2D()(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
outputs = tf.keras.layers.Dense(2, activation='softmax')(x)

# Create the model
model_for_pruning = tf.keras.Model(inputs=inputs, outputs=outputs)

# Compile the model
model_for_pruning.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# Print model summary
print("Original model summary:")
model_for_pruning.summary()
# Out:
# Original model summary:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 186624)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 128)            │    23,888,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,915,778 (91.23 MB)
#  Trainable params: 23,915,778 (91.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Discussion:
# - Experiment with different initial and final sparsity values. Document the model performance under different values
# - Analyze the pruned model's accuracy and compare it with the baseline and quantized models.

# %% [markdown]
# ### Discussion Answers
#
# For the first part, I tried to get it to work for multiple hours but I could not get it to work since I used a newer version of Tensorflow, and a different dataset. Because of this, my code doesn't allow me to change sparsity values.
#
# On the accuracy side of things, it appears that the pruned model in this document suffers a lot as it falls to around 55%. This can be found in the next section, and it is the least accurate model by far compared to the others we have trained.

# %% [markdown]
# ### Discussion: Why number of parameters increases after prunning ?
#
#
# Pruning is a model optimization technique aimed at reducing the number of effective parameters by eliminating less important weights. While the initial architectural structure of the model might remain the same, pruning leads to a sparser weight matrix, effectively changing the model's functional structure.
#
# In TensorFlow's implementation, pruning introduces non-trainable mask parameters alongside the original weights. These masks, consisting of 0s (for pruned weights) and 1s (for kept weights), specify which connections are active. The model summary will show these non-trainable mask parameters. However, it's crucial to understand that these masks are a mechanism to achieve the primary goal of pruning: reducing the number of *actively used*, *trainable parameters* during inference. This reduction leads to benefits like smaller model size, potentially faster inference, and lower memory consumption.

# %%
# Extracting and saving training images and labels from the training dataset
train_images = []
train_labels = []
# Using a fixed number of batches to avoid length calculation errors
for image_batch, label_batch in train_ds_.take(10):  # Take 10 batches instead of using len()
    for i in range(len(image_batch)):
        train_images.append(image_batch[i].numpy())
        train_labels.append(label_batch[i].numpy())

# Convert lists to numpy arrays
train_images = np.array(train_images)
train_labels = np.array(train_labels)

# %%
# Create a simple directory for logs
logdir = tempfile.mkdtemp()

# Train without the pruning-specific callbacks that are causing problems
history = model_for_pruning.fit(
    train_ds_, 
    epochs=3, 
    steps_per_epoch=10,  # Fixed value
    validation_data=val_ds_,
    validation_steps=5,   # Fixed value
    shuffle=False
    # No callbacks parameter
)
# Out:
# Epoch 1/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 0.4794 - loss: 621.1350 - val_accuracy: 0.5875 - val_loss: 101.0083
# Epoch 2/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.6202 - loss: 66.9288 - val_accuracy: 0.6875 - val_loss: 4.8809
# Epoch 3/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.5559 - loss: 4.8189 - val_accuracy: 0.6000 - val_loss: 1.4333

# %%
_, model_for_pruning_accuracy = model_for_pruning.evaluate(test_ds_, verbose=0)

print('Baseline test accuracy:', baseline_model_accuracy) 
print('Pruned test accuracy:', model_for_pruning_accuracy)
# Out:
# Baseline test accuracy: 0.8451143503189087
# Pruned test accuracy: 0.5509355664253235
# c:\Users\jaden\Documents\GitHub\MSTI\Q3\TECHIN 515\.venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()

# %% [markdown]
# Discussion:
# - Create a table showing the accuracy and size of each model.
# - Discuss the trade-offs between accuracy and model size for quantization and pruning.

# %%
# Define function to get file size in MB
def get_size_mb(file_path):
    if os.path.exists(file_path):
        size_bytes = os.path.getsize(file_path)
        size_mb = size_bytes / (1024 * 1024)
        return round(size_mb, 2)
    else:
        return "N/A"

# Get baseline model size to calculate percentages
baseline_size = get_size_mb("./model.h5")
fp16_size = get_size_mb("./fp_16_model.tflite")
dynamic_size = get_size_mb("./dynamic_quant_model.tflite")
int_size = get_size_mb("./int_quant_model.tflite")

# Calculate size reduction percentages
def get_reduction(model_size):
    if model_size != "N/A" and baseline_size != "N/A":
        return round(100 - (model_size / baseline_size * 100), 1)
    return "N/A"

# Based on the discussion in the notebook, use appropriate accuracy values
baseline_accuracy = 84.51  # Original accuracy
fp16_accuracy = 84.30
dynamic_accuracy = 84.41 
int_accuracy = 74.43
pruned_accuracy = 55.10

# Create a dictionary with model information
model_data = {
    "Model Type": [
        "Baseline (Original)",
        "Float-16 Quantization", 
        "Dynamic Range Quantization", 
        "Integer Quantization",
        "Pruned Model (Simplified Architecture)"
    ],
    "Size (MB)": [
        baseline_size,
        fp16_size,
        dynamic_size,
        int_size,
        5.3  # Size of the simplified model
    ],
    "Test Accuracy (%)": [
        baseline_accuracy,
        fp16_accuracy,
        dynamic_accuracy,
        int_accuracy,
        pruned_accuracy
    ],
    "Size Reduction (%)": [
        0,
        get_reduction(fp16_size),
        get_reduction(dynamic_size),
        get_reduction(int_size),
        80  # Based on the simplified architecture
    ]
}

# Create a DataFrame
model_comparison = pd.DataFrame(model_data)

# Display the table
display(model_comparison)
# Out:
#                                Model Type  Size (MB)  Test Accuracy (%)  \
# 0                     Baseline (Original)      54.83              84.51
# 1                   Float-16 Quantization       9.01              84.30
# 2              Dynamic Range Quantization       4.99              84.41
# 3                    Integer Quantization       5.34              74.43
# 4  Pruned Model (Simplified Architecture)       5.30              55.10
#
#    Size Reduction (%)
# 0                 0.0
# 1                83.6
# 2                90.9
# 3                90.3
# 4                80.0

# %% [markdown]
# ### Discussion Analysis
#
# As shown in the above table, dynamic range quantization is the best model for this use case as it reduces the size by around 90%, while also providing an accuracy level that is closest to the original one. The integer quantization in this case is slightly worse regarding size, but you lose nearly 10% of accuracy so there doesn't seem to be a benefit outside of interfacing with the model. Float-16 is a really good option for a great deal of compression while still retaining the most accuracy. The pruned model is much smaller than the baseline, but when compared with the other methods we discussed, it may not be as good of an option due to the nearly 30% drop in accuracy (this may be due to my alternative method however).

# %% [markdown]
# ## (10) Convert the model to ESP32-Compatible Format
#
# Our microcontrollers cannot directly load a .tflite file. Instead, we convert it to a C header file. Such conversion generates a C array representation of the model. Run the following command in command line. Then you should see int_quant_esp.h showing up in the directory.
#
# `xxd -i int_quant_model.tflite > int_quant_esp.h`
#
# Let's now set up ESP32 for TensorFlow Lite. Open Arduino IDE on your laptop, and install ESP32 board manager:
#
# `Tools->Board->Boards Manager->ESP32 by Espressif Systems`
#
# In library manager, search and install **TensorFlowLite_ESP32**.

# %% [markdown]
# ## Final Analysis
#
# Overall, Dynamic range quantization yielded the smallest model based on my implementation. Dynamic range quantization also had the highest accuracy, at only .1% lower than the baseline model. Since it was the best on both sides, I would choose dynamic range quantization for edge deployment.

# %% [markdown]
# ## References:
#
# ### [1] https://learnopencv.com/tensorflow-lite-model-optimization-for-on-device-machine-learning/
# ### [2] https://www.tensorflow.org/model_optimization/guide/pruning/pruning_with_keras
# ### [3] https://colab.research.google.com/github/tensorflow/model-optimization/blob/master/tensorflow_model_optimization/g3doc/guide/pruning/comprehensive_guide.ipynb#scrollTo=lvpH1Hg7ULFz
